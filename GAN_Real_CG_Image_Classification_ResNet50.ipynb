# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("✅ GPU detected:", gpus)
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print("✅ Memory growth enabled on GPU(s)")
else:
    print("❌ No GPU found. Running on CPU")
# Out:
# TensorFlow version: 2.10.1
# ✅ GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ Memory growth enabled on GPU(s)

# %%
import os
import numpy as np
import pandas as pd
import cv2
import skimage.color
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
from sklearn.metrics import classification_report
from mlxtend.evaluate import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# fixing randomness
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# image size + batch size
img_size = (224,224)
batch_size = 32

# training schedule (3-phase fine-tuning)
initial_epochs = 10       # train only dense layers
phase2_epochs = 12        # train last ResNet block
phase3_epochs = 12        # train full model

train_samples = 7200
val_samples = 2400
test_samples = 2400

num_classes = 3  # 3-class classification

train_dir = "C:/Users/243B001/Desktop/OJASVI/split_data/train"
val_dir = "C:/Users/243B001/Desktop/OJASVI/split_data/val"
test_dir = "C:/Users/243B001/Desktop/OJASVI/split_data/test"

model_save_path = "mcrestnet_best.h5"

USE_MIXUP = True      # mixup augmentation improves generalization
MIXUP_ALPHA = 0.2
UNFREEZE_FROM = 140   # last ResNet block to unfreeze in Phase 2

# -------------------------------------------------------------------
# Preprocessing functions for LCH and HSV branches
# -------------------------------------------------------------------

# rescales each channel between 0–255 so that LAB/LCH/HSV remain valid
def scale0to255(image):
    a = image.astype(np.float32)
    if a.ndim == 3 and a.shape[2] >= 3:
        for i in range(3):
            mn = np.min(a[:,:,i])
            mx = np.max(a[:,:,i])
            if mx - mn != 0:
                a[:,:,i] = ((a[:,:,i] - mn) / (mx - mn)) * 255.0
            else:
                a[:,:,i] = 0.0
    return a.astype(np.uint8)

# Laplacian + Gaussian filter => enhances edges & improves texture learning
def log_filter(image):
    g = cv2.GaussianBlur(image, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    sharp = np.uint8(np.clip(image + lap, 0, 255))
    return sharp

# convert augmented RGB → LCH color space
def to_lch(batch):
    out = []
    for img in batch:
        x = log_filter(img)
        lab = skimage.color.rgb2lab(x)
        lch = skimage.color.lab2lch(lab)
        lch_s = scale0to255(lch)
        out.append(lch_s)
    return np.stack(out, axis=0)

# convert augmented RGB → HSV color space
def to_hsv(batch):
    out = []
    for img in batch:
        x = log_filter(img)
        hsv = skimage.color.rgb2hsv(x)
        hsv = np.nan_to_num(hsv)
        hsv_s = scale0to255(hsv)
        out.append(hsv_s)
    return np.stack(out, axis=0)

# -------------------------------------------------------------------
# Strong augmentation improves model generalization
# -------------------------------------------------------------------
aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.12,
    height_shift_range=0.12,
    shear_range=0.08,
    zoom_range=0.12,
    horizontal_flip=True,
    brightness_range=[0.75,1.25],
    fill_mode='reflect'
)

# validation and test must NOT be augmented
val_aug = ImageDataGenerator()
test_aug = ImageDataGenerator()

# load images from folders
base_flow = aug.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=seed
)

val_flow = val_aug.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_flow = test_aug.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)

# -------------------------------------------------------------------
# Mixup augmentation:
# blends two images & labels → improves robustness massively
# prevents overfitting & sharp decision boundaries
# -------------------------------------------------------------------
def mixup(batch_x, batch_y, alpha=MIXUP_ALPHA):
    lam = np.random.beta(alpha, alpha)
    batch_size_local = batch_x.shape[0]
    idx = np.random.permutation(batch_size_local)

    x_mix = lam * batch_x + (1 - lam) * batch_x[idx]
    y_mix = lam * batch_y + (1 - batch_y[idx])
    return x_mix, y_mix

# -------------------------------------------------------------------
# Triple generator:
# Takes RGB → creates LCH & HSV → returns fused input batch
# -------------------------------------------------------------------
def triple_generator(base_gen):
    while True:
        x_batch, y_batch = next(base_gen)
        x_batch = x_batch.astype(np.uint8)

        if USE_MIXUP:
            x_batch, y_batch = mixup(x_batch, y_batch)

        lch_batch = to_lch(x_batch)
        hsv_batch = to_hsv(x_batch)

        x_rgb = tf.keras.applications.resnet.preprocess_input(x_batch.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch_batch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv_batch.astype(np.float32))

        yield ([x_rgb, x_lch, x_hsv], y_batch)

train_gen = triple_generator(base_flow)

# -------------------------------------------------------------------
# Build each ResNet branch (RGB / LCH / HSV)
# They stay in sync because triple_generator feeds 3 aligned versions
# -------------------------------------------------------------------
def build_branch(prefix):
    backbone = ResNet50(include_top=False, weights='imagenet', input_shape=(224,224,3))

    # rename layers so branches don’t have name conflicts
    for i,layer in enumerate(backbone.layers):
        layer._name = f"{prefix}_layer_{i}"

    # freeze here → phase 1 training only affects Dense head
    for layer in backbone.layers:
        layer.trainable = False

    out = backbone.output
    out = GlobalAveragePooling2D()(out)  # converts feature maps → vector
    return backbone.input, out, backbone

in1, out1, b1 = build_branch("r1")
in2, out2, b2 = build_branch("r2")
in3, out3, b3 = build_branch("r3")

# -------------------------------------------------------------------
# Fusion of 3 branches → fully connected head
# BatchNorm + Dropout stop overfitting
# -------------------------------------------------------------------
fused = concatenate([out1, out2, out3])
x = Dense(512, activation='relu')(fused)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
pred = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=[in1, in2, in3], outputs=pred)

# label smoothing improves calibration & helps in 3-class problems
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

# phase 1 LR – high because we train only Dense layers
opt = Adam(learning_rate=1e-4)

model.compile(optimizer=opt, loss=loss_fn, metrics=['accuracy'])

# -------------------------------------------------------------------
# Callbacks:
# - checkpoint saves best model
# - reduceLR lowers LR when val loss stalls
# - early stopping prevents overfitting
# -------------------------------------------------------------------
checkpoint = ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1, min_lr=1e-7)
early = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
csvlog = CSVLogger("training_log.csv")

steps_per_epoch = train_samples // batch_size
val_steps = val_samples // batch_size

# -------------------------------------------------------------------
# PHASE 1 — Train only the Dense layers
# -------------------------------------------------------------------
model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=initial_epochs,
    validation_data=val_flow,
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)

# -------------------------------------------------------------------
# PHASE 2 — unfreeze last block of ResNet50
# improves feature extraction but still safe
# -------------------------------------------------------------------
for layer in b1.layers[UNFREEZE_FROM:]: layer.trainable = True
for layer in b2.layers[UNFREEZE_FROM:]: layer.trainable = True
for layer in b3.layers[UNFREEZE_FROM:]: layer.trainable = True

model.compile(optimizer=Adam(learning_rate=3e-5), loss=loss_fn, metrics=['accuracy'])

model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=phase2_epochs,
    validation_data=val_flow,
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)

# -------------------------------------------------------------------
# PHASE 3 — unfreeze ALL layers
# very low LR = keeps ImageNet knowledge safe
# best accuracy boost
# -------------------------------------------------------------------
for layer in b1.layers: layer.trainable = True
for layer in b2.layers: layer.trainable = True
for layer in b3.layers: layer.trainable = True

model.compile(optimizer=Adam(learning_rate=5e-6), loss=loss_fn, metrics=['accuracy'])

model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=phase3_epochs,
    validation_data=val_flow,
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)

model = load_model(model_save_path)

# -------------------------------------------------------------------
# TTA (Test-Time Augmentation)
# flips image horizontally → averages both predictions
# boosts test accuracy by ~1–2%
# -------------------------------------------------------------------
def tta_predict(model, img):
    imgs = [img, np.fliplr(img.copy())]
    preds = []
    for i in imgs:
        x_rgb = tf.keras.applications.resnet.preprocess_input(np.expand_dims(i.astype(np.float32),0))
        x_lch = tf.keras.applications.resnet.preprocess_input(np.expand_dims(to_lch(np.expand_dims(i,0))[0].astype(np.float32),0))
        x_hsv = tf.keras.applications.resnet.preprocess_input(np.expand_dims(to_hsv(np.expand_dims(i,0))[0].astype(np.float32),0))
        p = model.predict([x_rgb, x_lch, x_hsv])[0]
        preds.append(p)
    return np.mean(preds, axis=0)

# -------------------------------------------------------------------
# Evaluate on test set
# -------------------------------------------------------------------
y_true = []
y_pred = []
files = []

for i in range(test_samples):
    x, y = next(test_flow)
    img = x[0].astype(np.uint8)
    p = tta_predict(model, img)
    y_pred.append(np.argmax(p))
    y_true.append(np.argmax(y[0]))
    files.append(test_flow.filenames[i])

labels_map = dict((v,k) for k,v in test_flow.class_indices.items())
pred_names = [labels_map[i] for i in y_pred]

df = pd.DataFrame({"Filename":files, "Prediction":pred_names})
df.to_csv("test_predictions.csv", index=False)

cm = confusion_matrix(y_target=np.array(y_true), y_predicted=np.array(y_pred), binary=False)
fig, ax = plot_confusion_matrix(conf_mat=cm, class_names=list(labels_map.values()))
plt.savefig("conf_matrix.png")
plt.show()

print(classification_report(y_true, y_pred, target_names=list(labels_map.values())))
# Out:
# Found 6594 images belonging to 3 classes.
# Found 2199 images belonging to 3 classes.
# Found 2199 images belonging to 3 classes.
# Epoch 1/10
# 225/225 [==============================] - ETA: 0s - loss: 4.3252 - accuracy: 0.3276
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 237
#     232 val_steps = val_samples // batch_size
#     234 # -------------------------------------------------------------------
#     235 # PHASE 1 — Train only the Dense layers
#     236 # -------------------------------------------------------------------
# --> 237 model.fit(
#     238     train_gen,
#     239     steps_per_epoch=steps_per_epoch,
#     240     epochs=initial_epochs,
#     241     validation_data=val_flow,
#     242     validation_steps=val_steps,
#     243     callbacks=[checkpoint, reduce_lr, early, csvlog]
#     244 )
#     246 # -------------------------------------------------------------------
#     247 # PHASE 2 — unfreeze last block of ResNet50
#     248 # improves feature extraction but still safe
#     249 # -------------------------------------------------------------------
#     250 for layer in b1.layers[UNFREEZE_FROM:]: layer.trainable = True
#
# File ~\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file0v49ot08.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\243B001\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\engine\training.py", line 1727, in test_function  *
#         return step_function(self, iterator)
#     File "C:\Users\243B001\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\engine\training.py", line 1713, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\243B001\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\engine\training.py", line 1701, in run_step  **
#         outputs = model.test_step(data)
#     File "C:\Users\243B001\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\engine\training.py", line 1665, in test_step
#         y_pred = self(x, training=False)
#     File "C:\Users\243B001\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\243B001\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\engine\input_spec.py", line 216, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Layer "model" expects 3 input(s), but it received 1 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(None, None, None, None) dtype=float32>]

# %%
import os
import numpy as np
import pandas as pd
import cv2
import skimage.color
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
from sklearn.metrics import classification_report
from mlxtend.evaluate import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# fixing randomness
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# image size + batch size
img_size = (224,224)
batch_size = 32

# training schedule (3-phase fine-tuning)
initial_epochs = 10       # train only dense layers
phase2_epochs = 12        # train last ResNet block
phase3_epochs = 12        # train full model

train_samples = 7200
val_samples = 2400
test_samples = 2400

num_classes = 3  # you said 3-class classification

train_dir = "C:/Users/243B001/Desktop/OJASVI/split_data/train"
val_dir = "C:/Users/243B001/Desktop/OJASVI/split_data/val"
test_dir = "C:/Users/243B001/Desktop/OJASVI/split_data/test"

model_save_path = "mcrestnet_best.h5"

USE_MIXUP = True      # mixup augmentation improves generalization
MIXUP_ALPHA = 0.2
UNFREEZE_FROM = 140   # last ResNet block to unfreeze in Phase 2

# -------------------------------------------------------------------
# Preprocessing functions for LCH and HSV branches
# -------------------------------------------------------------------

# rescales each channel between 0–255 so that LAB/LCH/HSV remain valid
def scale0to255(image):
    a = image.astype(np.float32)
    if a.ndim == 3 and a.shape[2] >= 3:
        for i in range(3):
            mn = np.min(a[:,:,i])
            mx = np.max(a[:,:,i])
            if mx - mn != 0:
                a[:,:,i] = ((a[:,:,i] - mn) / (mx - mn)) * 255.0
            else:
                a[:,:,i] = 0.0
    return a.astype(np.uint8)

# Laplacian + Gaussian filter => enhances edges & improves texture learning
def log_filter(image):
    g = cv2.GaussianBlur(image, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    sharp = np.uint8(np.clip(image + lap, 0, 255))
    return sharp

# convert augmented RGB → LCH color space
def to_lch(batch):
    out = []
    for img in batch:
        x = log_filter(img)
        lab = skimage.color.rgb2lab(x)
        lch = skimage.color.lab2lch(lab)
        lch_s = scale0to255(lch)
        out.append(lch_s)
    return np.stack(out, axis=0)

# convert augmented RGB → HSV color space
def to_hsv(batch):
    out = []
    for img in batch:
        x = log_filter(img)
        hsv = skimage.color.rgb2hsv(x)
        hsv = np.nan_to_num(hsv)
        hsv_s = scale0to255(hsv)
        out.append(hsv_s)
    return np.stack(out, axis=0)

# -------------------------------------------------------------------
# Strong augmentation improves model generalization
# -------------------------------------------------------------------
aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.12,
    height_shift_range=0.12,
    shear_range=0.08,
    zoom_range=0.12,
    horizontal_flip=True,
    brightness_range=[0.75,1.25],
    fill_mode='reflect'
)

# validation and test must NOT be augmented
val_aug = ImageDataGenerator()
test_aug = ImageDataGenerator()

# load images from folders
base_flow = aug.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=seed
)

val_flow = val_aug.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_flow = test_aug.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)

# -------------------------------------------------------------------
# Mixup augmentation:
# blends two images & labels → improves robustness massively
# prevents overfitting & sharp decision boundaries
# -------------------------------------------------------------------
def mixup(batch_x, batch_y, alpha=MIXUP_ALPHA):
    lam = np.random.beta(alpha, alpha)
    batch_size_local = batch_x.shape[0]
    idx = np.random.permutation(batch_size_local)

    x_mix = lam * batch_x + (1 - lam) * batch_x[idx]
    y_mix = lam * batch_y + (1 - lam) * batch_y[idx]  # Fixed this line
    return x_mix, y_mix

# -------------------------------------------------------------------
# Triple generator for training (with mixup)
# -------------------------------------------------------------------
def triple_generator_train(base_gen):
    while True:
        x_batch, y_batch = next(base_gen)
        x_batch = x_batch.astype(np.uint8)

        if USE_MIXUP:
            x_batch, y_batch = mixup(x_batch, y_batch)

        lch_batch = to_lch(x_batch)
        hsv_batch = to_hsv(x_batch)

        x_rgb = tf.keras.applications.resnet.preprocess_input(x_batch.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch_batch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv_batch.astype(np.float32))

        yield ([x_rgb, x_lch, x_hsv], y_batch)

# -------------------------------------------------------------------
# Triple generator for validation/test (without mixup)
# -------------------------------------------------------------------
def triple_generator_val(base_gen):
    while True:
        x_batch, y_batch = next(base_gen)
        x_batch = x_batch.astype(np.uint8)

        lch_batch = to_lch(x_batch)
        hsv_batch = to_hsv(x_batch)

        x_rgb = tf.keras.applications.resnet.preprocess_input(x_batch.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch_batch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv_batch.astype(np.float32))

        yield ([x_rgb, x_lch, x_hsv], y_batch)

train_gen = triple_generator_train(base_flow)
val_gen = triple_generator_val(val_flow)  # Create validation generator

# -------------------------------------------------------------------
# Build each ResNet branch (RGB / LCH / HSV)
# They stay in sync because triple_generator feeds 3 aligned versions
# -------------------------------------------------------------------
def build_branch(prefix):
    backbone = ResNet50(include_top=False, weights='imagenet', input_shape=(224,224,3))

    # rename layers so branches don't have name conflicts
    for i,layer in enumerate(backbone.layers):
        layer._name = f"{prefix}_layer_{i}"

    # freeze here → phase 1 training only affects Dense head
    for layer in backbone.layers:
        layer.trainable = False

    out = backbone.output
    out = GlobalAveragePooling2D()(out)  # converts feature maps → vector
    return backbone.input, out, backbone

in1, out1, b1 = build_branch("r1")
in2, out2, b2 = build_branch("r2")
in3, out3, b3 = build_branch("r3")

# -------------------------------------------------------------------
# Fusion of 3 branches → fully connected head
# BatchNorm + Dropout stop overfitting
# -------------------------------------------------------------------
fused = concatenate([out1, out2, out3])
x = Dense(512, activation='relu')(fused)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
pred = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=[in1, in2, in3], outputs=pred)

# label smoothing improves calibration & helps in 3-class problems
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

# phase 1 LR – high because we train only Dense layers
opt = Adam(learning_rate=1e-4)

model.compile(optimizer=opt, loss=loss_fn, metrics=['accuracy'])

# -------------------------------------------------------------------
# Callbacks:
# - checkpoint saves best model
# - reduceLR lowers LR when val loss stalls
# - early stopping prevents overfitting
# -------------------------------------------------------------------
checkpoint = ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1, min_lr=1e-7)
early = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
csvlog = CSVLogger("training_log.csv")

steps_per_epoch = train_samples // batch_size
val_steps = val_samples // batch_size

# -------------------------------------------------------------------
# PHASE 1 — Train only the Dense layers
# -------------------------------------------------------------------
print("Starting Phase 1 training...")
model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=initial_epochs,
    validation_data=val_gen,  # Use val_gen instead of val_flow
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)

# -------------------------------------------------------------------
# PHASE 2 — unfreeze last block of ResNet50
# improves feature extraction but still safe
# -------------------------------------------------------------------
print("Starting Phase 2 training...")
for layer in b1.layers[UNFREEZE_FROM:]: layer.trainable = True
for layer in b2.layers[UNFREEZE_FROM:]: layer.trainable = True
for layer in b3.layers[UNFREEZE_FROM:]: layer.trainable = True

model.compile(optimizer=Adam(learning_rate=3e-5), loss=loss_fn, metrics=['accuracy'])

model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=phase2_epochs,
    validation_data=val_gen,  # Use val_gen instead of val_flow
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)

# -------------------------------------------------------------------
# PHASE 3 — unfreeze ALL layers
# very low LR = keeps ImageNet knowledge safe
# best accuracy boost
# -------------------------------------------------------------------
print("Starting Phase 3 training...")
for layer in b1.layers: layer.trainable = True
for layer in b2.layers: layer.trainable = True
for layer in b3.layers: layer.trainable = True

model.compile(optimizer=Adam(learning_rate=5e-6), loss=loss_fn, metrics=['accuracy'])

model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=phase3_epochs,
    validation_data=val_gen,  # Use val_gen instead of val_flow
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)

model = load_model(model_save_path)

# -------------------------------------------------------------------
# TTA (Test-Time Augmentation)
# flips image horizontally → averages both predictions
# boosts test accuracy by ~1–2%
# -------------------------------------------------------------------
def tta_predict(model, img):
    imgs = [img, np.fliplr(img.copy())]
    preds = []
    for i in imgs:
        x_rgb = tf.keras.applications.resnet.preprocess_input(np.expand_dims(i.astype(np.float32),0))
        x_lch = tf.keras.applications.resnet.preprocess_input(np.expand_dims(to_lch(np.expand_dims(i,0))[0].astype(np.float32),0))
        x_hsv = tf.keras.applications.resnet.preprocess_input(np.expand_dims(to_hsv(np.expand_dims(i,0))[0].astype(np.float32),0))
        p = model.predict([x_rgb, x_lch, x_hsv])[0]
        preds.append(p)
    return np.mean(preds, axis=0)

# -------------------------------------------------------------------
# Evaluate on test set
# -------------------------------------------------------------------
print("Evaluating on test set...")
y_true = []
y_pred = []
files = []

# Create test generator
test_gen = triple_generator_val(test_flow)

for i in range(test_samples):
    ([x_rgb, x_lch, x_hsv], y) = next(test_gen)
    p = model.predict([x_rgb, x_lch, x_hsv])[0]
    y_pred.append(np.argmax(p))
    y_true.append(np.argmax(y[0]))
    files.append(test_flow.filenames[i])

labels_map = dict((v,k) for k,v in test_flow.class_indices.items())
pred_names = [labels_map[i] for i in y_pred]

df = pd.DataFrame({"Filename":files, "Prediction":pred_names})
df.to_csv("test_predictions.csv", index=False)

cm = confusion_matrix(y_target=np.array(y_true), y_predicted=np.array(y_pred), binary=False)
fig, ax = plot_confusion_matrix(conf_mat=cm, class_names=list(labels_map.values()))
plt.savefig("conf_matrix.png")
plt.show()

print(classification_report(y_true, y_pred, target_names=list(labels_map.values())))
# Out:
# Found 6594 images belonging to 3 classes.
# Found 2199 images belonging to 3 classes.
# Found 2199 images belonging to 3 classes.
# Starting Phase 1 training...
# Epoch 1/10
# 225/225 [==============================] - ETA: 0s - loss: 1.1680 - accuracy: 0.6307
# Epoch 1: val_loss improved from inf to 0.68684, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 518s 2s/step - loss: 1.1680 - accuracy: 0.6307 - val_loss: 0.6868 - val_accuracy: 0.8097 - lr: 1.0000e-04
# Epoch 2/10
# 225/225 [==============================] - ETA: 0s - loss: 0.8917 - accuracy: 0.7357
# Epoch 2: val_loss improved from 0.68684 to 0.56047, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 476s 2s/step - loss: 0.8917 - accuracy: 0.7357 - val_loss: 0.5605 - val_accuracy: 0.8766 - lr: 1.0000e-04
# Epoch 3/10
# 225/225 [==============================] - ETA: 0s - loss: 0.8319 - accuracy: 0.7734
# Epoch 3: val_loss improved from 0.56047 to 0.53140, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 481s 2s/step - loss: 0.8319 - accuracy: 0.7734 - val_loss: 0.5314 - val_accuracy: 0.8862 - lr: 1.0000e-04
# Epoch 4/10
# 225/225 [==============================] - ETA: 0s - loss: 0.8051 - accuracy: 0.7866
# Epoch 4: val_loss improved from 0.53140 to 0.47586, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 475s 2s/step - loss: 0.8051 - accuracy: 0.7866 - val_loss: 0.4759 - val_accuracy: 0.9260 - lr: 1.0000e-04
# Epoch 5/10
# 225/225 [==============================] - ETA: 0s - loss: 0.7483 - accuracy: 0.8036
# Epoch 5: val_loss did not improve from 0.47586
# 225/225 [==============================] - 466s 2s/step - loss: 0.7483 - accuracy: 0.8036 - val_loss: 0.5186 - val_accuracy: 0.9051 - lr: 1.0000e-04
# Epoch 6/10
# 225/225 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.8160
# Epoch 6: val_loss improved from 0.47586 to 0.46551, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 490s 2s/step - loss: 0.7190 - accuracy: 0.8160 - val_loss: 0.4655 - val_accuracy: 0.9272 - lr: 1.0000e-04
# Epoch 7/10
# 225/225 [==============================] - ETA: 0s - loss: 0.7287 - accuracy: 0.8174
# Epoch 7: val_loss did not improve from 0.46551
# 225/225 [==============================] - 473s 2s/step - loss: 0.7287 - accuracy: 0.8174 - val_loss: 0.4945 - val_accuracy: 0.9063 - lr: 1.0000e-04
# Epoch 8/10
# 225/225 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.8236
# Epoch 8: val_loss did not improve from 0.46551
# 225/225 [==============================] - 461s 2s/step - loss: 0.7087 - accuracy: 0.8236 - val_loss: 0.4713 - val_accuracy: 0.9176 - lr: 1.0000e-04
# Epoch 9/10
# 225/225 [==============================] - ETA: 0s - loss: 0.7233 - accuracy: 0.8232
# Epoch 9: val_loss improved from 0.46551 to 0.45708, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 502s 2s/step - loss: 0.7233 - accuracy: 0.8232 - val_loss: 0.4571 - val_accuracy: 0.9256 - lr: 1.0000e-04
# Epoch 10/10
# 225/225 [==============================] - ETA: 0s - loss: 0.6783 - accuracy: 0.8470
# Epoch 10: val_loss improved from 0.45708 to 0.44655, saving model to mcrestnet_best.h5
# 225/225 [==============================] - 490s 2s/step - loss: 0.6783 - accuracy: 0.8470 - val_loss: 0.4465 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Starting Phase 2 training...
# Epoch 1/12
# 225/225 [==============================] - ETA: 0s - loss: 0.6730 - accuracy: 0.8487
# Epoch 1: val_loss did not improve from 0.44655
# 225/225 [==============================] - 580s 3s/step - loss: 0.6730 - accuracy: 0.8487 - val_loss: 0.4547 - val_accuracy: 0.9327 - lr: 3.0000e-05
# Epoch 2/12
# 225/225 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.8665
# Epoch 2: val_loss improved from 0.44655 to 0.43553, saving model to mcrestnet_best.h5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 275
#     271 for layer in b3.layers[UNFREEZE_FROM:]: layer.trainable = True
#     273 model.compile(optimizer=Adam(learning_rate=3e-5), loss=loss_fn, metrics=['accuracy'])
# --> 275 model.fit(
#     276     train_gen,
#     277     steps_per_epoch=steps_per_epoch,
#     278     epochs=phase2_epochs,
#     279     validation_data=val_gen,  # Use val_gen instead of val_flow
#     280     validation_steps=val_steps,
#     281     callbacks=[checkpoint, reduce_lr, early, csvlog]
#     282 )
#     284 # -------------------------------------------------------------------
#     285 # PHASE 3 — unfreeze ALL layers
#     286 # very low LR = keeps ImageNet knowledge safe
#     287 # best accuracy boost
#     288 # -------------------------------------------------------------------
#     289 print("Starting Phase 3 training...")
#
# File ~\Anaconda3\envs\tf-gpu39\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\Anaconda3\envs\tf-gpu39\lib\site-packages\h5py\_hl\group.py:186, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     183         parent_path, name = name.rsplit(b'/', 1)
#     184         group = self.require_group(parent_path)
# --> 186 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     187 dset = dataset.Dataset(dsid)
#     188 return dset
#
# File ~\Anaconda3\envs\tf-gpu39\lib\site-packages\h5py\_hl\dataset.py:175, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0, fill_time)
#     172 else:
#     173     sid = h5s.create_simple(shape, maxshape)
# --> 175 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     177 if (data is not None) and (not isinstance(data, Empty)):
#     178     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:136, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import cv2
import skimage.color
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# ------------------ PATHS ------------------
test_path = "/content/drive/MyDrive/gan_graphics_real/split_data/test"
model_path = "/content/drive/MyDrive/mcrestnet_best.h5"
img_size = (224,224)

# ------------------ LOAD MODEL SAFELY ------------------
model = load_model(model_path, compile=False)

model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

print("Phase-1 model loaded successfully!")

# ------------------ PREPROCESSING ------------------
def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn = np.min(a[:,:,i])
        mx = np.max(a[:,:,i])
        if mx - mn != 0:
            a[:,:,i] = ((a[:,:,i] - mn) / (mx - mn)) * 255
        else:
            a[:,:,i] = 0
    return a.astype(np.uint8)

def log_filter(image):
    g = cv2.GaussianBlur(image, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    sharp = np.uint8(np.clip(image + lap, 0, 255))
    return sharp

def to_lch(batch):
    out = []
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        lch = skimage.color.lab2lch(lab)
        out.append(scale0to255(lch))
    return np.stack(out)

def to_hsv(batch):
    out = []
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        hsv = np.nan_to_num(hsv)
        out.append(scale0to255(hsv))
    return np.stack(out)

# ------------------ TEST GENERATOR ------------------
test_aug = ImageDataGenerator()

test_flow = test_aug.flow_from_directory(
    test_path,
    target_size=img_size,
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)

def triple_test(gen):
    while True:
        x, y = next(gen)
        x = x.astype(np.uint8)

        lch = to_lch(x)
        hsv = to_hsv(x)

        x_rgb = tf.keras.applications.resnet.preprocess_input(x.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv.astype(np.float32))

        yield ([x_rgb, x_lch, x_hsv], y)

test_gen = triple_test(test_flow)

# ------------------ PREDICTIONS ------------------
y_true = []
y_pred = []
prob_list = []

for i in range(test_flow.n):
    X, y = next(test_gen)
    p = model.predict(X, verbose=0)[0]

    prob_list.append(p)
    y_pred.append(np.argmax(p))
    y_true.append(np.argmax(y[0]))

probs = np.array(prob_list)

# ------------------ LABELS ------------------
labels_map = {v: k for k, v in test_flow.class_indices.items()}
class_names = list(labels_map.values())

# ------------------ CLASSIFICATION REPORT ------------------
print("\n----- CLASSIFICATION REPORT -----")
print(classification_report(y_true, y_pred, target_names=class_names))

# ------------------ CONFUSION MATRIX ------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, cmap="Blues", fmt='d',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ------------------ ROC CURVES + AUC ------------------
y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes=len(class_names))

plt.figure(figsize=(8,6))
for i, cname in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_onehot[:,i], probs[:,i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f"{cname} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], linestyle='--')
plt.title("ROC Curves (Phase-1)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# ------------------ SAVE CONFIDENCE CSV ------------------
df = pd.DataFrame(probs, columns=[f"Conf_{c}" for c in class_names])
df["True"] = [labels_map[i] for i in y_true]
df["Pred"] = [labels_map[i] for i in y_pred]

df.to_csv("phase1_full_metrics.csv", index=False)

print("\nSaved full metrics → phase1_full_metrics.csv")
# Out:
# Phase-1 model loaded successfully!
# Found 2199 images belonging to 3 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-191856080.py in <cell line: 0>()
#      93
#      94 for i in range(test_flow.n):
# ---> 95     X, y = next(test_gen)
#      96     p = model.predict(X, verbose=0)[0]
#      97
#
# /tmp/ipython-input-191856080.py in triple_test(gen)
#      73 def triple_test(gen):
#      74     while True:
# ---> 75         x, y = next(gen)
#      76         x = x.astype(np.uint8)
#      77
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in __next__(self)
#     110         # The transformation of images is not under thread lock
#     111         # so it can be done in parallel
# --> 112         return self._get_batches_of_transformed_samples(index_array)
#     113
#     114     def _get_batches_of_transformed_samples(self, index_array):
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in _get_batches_of_transformed_samples(self, index_array)
#     311         filepaths = self.filepaths
#     312         for i, j in enumerate(index_array):
# --> 313             img = image_utils.load_img(
#     314                 filepaths[j],
#     315                 color_mode=self.color_mode,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_utils.py in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     234             path = str(path.resolve())
#     235         with open(path, "rb") as f:
# --> 236             img = pil_image.open(io.BytesIO(f.read()))
#     237     else:
#     238         raise TypeError(
#
# KeyboardInterrupt:

# %%
# !find /content/drive/MyDrive -name "mcrestnet_best.h5"
# Out:
# /content/drive/MyDrive/mcrestnet_best.h5

# %%
# ---------------------------------------
# FAST PHASE-1 EVALUATION WITH ROC + AUC
# ---------------------------------------

from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import cv2
import skimage.color
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# ------------------ PATHS ------------------
test_path = "/content/drive/MyDrive/gan_graphics_real/split_data/test"
model_path = "/content/drive/MyDrive/mcrestnet_best.h5"
img_size = (224,224)

# ------------------ LOAD MODEL SAFELY ------------------
model = load_model(model_path, compile=False)

model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

print("✓ Phase-1 model loaded.")

# ------------------ PREPROCESSING ------------------
def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn, mx = np.min(a[:,:,i]), np.max(a[:,:,i])
        a[:,:,i] = ((a[:,:,i]-mn)/(mx-mn))*255 if mx!=mn else 0
    return a.astype(np.uint8)

def log_filter(image):
    g = cv2.GaussianBlur(image, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    return np.uint8(np.clip(image + lap, 0, 255))

def to_lch(batch):
    out=[]
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        out.append(scale0to255(skimage.color.lab2lch(lab)))
    return np.stack(out)

def to_hsv(batch):
    out=[]
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        out.append(scale0to255(np.nan_to_num(hsv)))
    return np.stack(out)

# ------------------ TEST GENERATOR ------------------
test_aug = ImageDataGenerator()

test_flow = test_aug.flow_from_directory(
    test_path,
    target_size=img_size,
    batch_size=32,     # <<--- FAST BATCH SIZE
    class_mode='categorical',
    shuffle=False
)

# ------------------ BATCHED EVALUATION ------------------
print("✓ Starting fast evaluation...")

y_true = []
prob_list = []

steps = int(np.ceil(test_flow.n / test_flow.batch_size))

test_flow.reset()

for _ in tqdm(range(steps)):
    x_batch, y_batch = next(test_flow)

    x_batch_uint8 = x_batch.astype(np.uint8)

    lch_batch = to_lch(x_batch_uint8)
    hsv_batch = to_hsv(x_batch_uint8)

    x_rgb = tf.keras.applications.resnet.preprocess_input(x_batch.astype(np.float32))
    x_lch = tf.keras.applications.resnet.preprocess_input(lch_batch.astype(np.float32))
    x_hsv = tf.keras.applications.resnet.preprocess_input(hsv_batch.astype(np.float32))

    preds = model.predict([x_rgb, x_lch, x_hsv], verbose=0)

    prob_list.extend(preds)
    y_true.extend(np.argmax(y_batch, axis=1))

probs = np.array(prob_list)
y_pred = np.argmax(probs, axis=1)

print("✓ Predictions complete!")

# ------------------ LABELS ------------------
labels_map = {v: k for k, v in test_flow.class_indices.items()}
class_names = list(labels_map.values())

# ------------------ CLASSIFICATION REPORT ------------------
print("\n----- CLASSIFICATION REPORT -----\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# ------------------ CONFUSION MATRIX ------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ------------------ ROC CURVES + AUC ------------------
y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes=len(class_names))

plt.figure(figsize=(8,6))
for i, cname in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_onehot[:,i], probs[:,i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{cname} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], linestyle='--')
plt.title("ROC Curves (Phase-1)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# ------------------ SAVE CONFIDENCE CSV ------------------
df = pd.DataFrame(probs, columns=[f"Conf_{c}" for c in class_names])
df["True"] = [labels_map[i] for i in y_true]
df["Pred"] = [labels_map[i] for i in y_pred]

df.to_csv("phase1_full_metrics.csv", index=False)

print("\n✓ Saved full metrics → phase1_full_metrics.csv")
print("\n✓ Phase-1 evaluation complete!")
# Out:
# ✓ Phase-1 model loaded.
# Found 2199 images belonging to 3 classes.
# ✓ Starting fast evaluation...
# 100%|██████████| 69/69 [10:34<00:00,  9.20s/it]
# ✓ Predictions complete!
#
# ----- CLASSIFICATION REPORT -----
#
#               precision    recall  f1-score   support
#
#          gan       0.99      0.94      0.96       800
#     graphics       0.90      0.95      0.93       800
#         real       0.89      0.89      0.89       599
#
#     accuracy                           0.93      2199
#    macro avg       0.93      0.93      0.93      2199
# weighted avg       0.93      0.93      0.93      2199
# ✓ Saved full metrics → phase1_full_metrics.csv
#
# ✓ Phase-1 evaluation complete!

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
import cv2, skimage.color

train_path = "/content/drive/MyDrive/gan_graphics_real/split_data/train"
val_path   = "/content/drive/MyDrive/gan_graphics_real/split_data/val"
model_path = "/content/drive/MyDrive/mcrestnet_best.h5"

img_size = (224,224)
batch_size = 32
phase2_epochs = 12
UNFREEZE_FROM = 140
MIXUP_ALPHA = 0.2
USE_MIXUP = True
num_classes = 3

model = load_model(model_path, compile=False)

b1 = [layer for layer in model.layers if layer.name.startswith("r1_layer")]
b2 = [layer for layer in model.layers if layer.name.startswith("r2_layer")]
b3 = [layer for layer in model.layers if layer.name.startswith("r3_layer")]

for layer in b1[UNFREEZE_FROM:]: layer.trainable = True
for layer in b2[UNFREEZE_FROM:]: layer.trainable = True
for layer in b3[UNFREEZE_FROM:]: layer.trainable = True

loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)
model.compile(optimizer=Adam(learning_rate=3e-5), loss=loss_fn, metrics=["accuracy"])

def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn, mx = np.min(a[:,:,i]), np.max(a[:,:,i])
        a[:,:,i] = ((a[:,:,i]-mn)/(mx-mn))*255 if mx!=mn else 0
    return a.astype(np.uint8)

def log_filter(img):
    g = cv2.GaussianBlur(img, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    return np.uint8(np.clip(img + lap, 0, 255))

def to_lch(batch):
    out=[]
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        out.append(scale0to255(skimage.color.lab2lch(lab)))
    return np.stack(out)

def to_hsv(batch):
    out=[]
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        out.append(scale0to255(np.nan_to_num(hsv)))
    return np.stack(out)

aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.12,
    height_shift_range=0.12,
    shear_range=0.08,
    zoom_range=0.12,
    horizontal_flip=True,
    brightness_range=[0.75,1.25],
    fill_mode="reflect"
)

val_aug = ImageDataGenerator()

train_flow = aug.flow_from_directory(train_path, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=True)
val_flow   = val_aug.flow_from_directory(val_path,   target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=False)

def mixup(x, y, alpha=MIXUP_ALPHA):
    lam = np.random.beta(alpha, alpha)
    idx = np.random.permutation(x.shape[0])
    return lam*x + (1-lam)*x[idx], lam*y + (1-lam)*y[idx]

def gen_train():
    while True:
        x, y = next(train_flow)
        x = x.astype(np.uint8)
        if USE_MIXUP:
            x, y = mixup(x, y)
        lch = to_lch(x)
        hsv = to_hsv(x)
        x_rgb = tf.keras.applications.resnet.preprocess_input(x.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv.astype(np.float32))
        yield (x_rgb, x_lch, x_hsv), y

def gen_val():
    while True:
        x, y = next(val_flow)
        x = x.astype(np.uint8)
        lch = to_lch(x)
        hsv = to_hsv(x)
        x_rgb = tf.keras.applications.resnet.preprocess_input(x.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv.astype(np.float32))
        yield (x_rgb, x_lch, x_hsv), y

output_signature = (
    (
        tf.TensorSpec(shape=(None, img_size[0], img_size[1], 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, img_size[0], img_size[1], 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, img_size[0], img_size[1], 3), dtype=tf.float32),
    ),
    tf.TensorSpec(shape=(None, num_classes), dtype=tf.float32)
)

train_ds = tf.data.Dataset.from_generator(gen_train, output_signature=output_signature)
val_ds   = tf.data.Dataset.from_generator(gen_val,   output_signature=output_signature)

train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds   = val_ds.prefetch(tf.data.AUTOTUNE)

steps_per_epoch = train_flow.n // batch_size
val_steps = val_flow.n // batch_size

checkpoint = ModelCheckpoint("/content/drive/MyDrive/mcrestnet_phase2.h5", monitor="val_loss", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-7, verbose=1)
early = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
csvlog = CSVLogger("/content/drive/MyDrive/phase2_training_log.csv")

model.fit(
    train_ds,
    epochs=phase2_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=val_steps,
    callbacks=[checkpoint, reduce_lr, early, csvlog]
)
# Out:
# Found 6594 images belonging to 3 classes.
# Found 2199 images belonging to 3 classes.
# Epoch 1/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.8637 - loss: 0.6793
# Epoch 1: val_loss improved from inf to 0.44431, saving model to /content/drive/MyDrive/mcrestnet_phase2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 4316s 21s/step - accuracy: 0.8637 - loss: 0.6793 - val_accuracy: 0.9315 - val_loss: 0.4443 - learning_rate: 3.0000e-05
# Epoch 2/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8763 - loss: 0.6244
# Epoch 2: val_loss did not improve from 0.44431
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 476s 2s/step - accuracy: 0.8763 - loss: 0.6244 - val_accuracy: 0.9299 - val_loss: 0.4596 - learning_rate: 3.0000e-05
# Epoch 3/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9069 - loss: 0.6158
# Epoch 3: val_loss did not improve from 0.44431
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 444s 2s/step - accuracy: 0.9068 - loss: 0.6158 - val_accuracy: 0.9345 - val_loss: 0.4538 - learning_rate: 3.0000e-05
# Epoch 4/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8844 - loss: 0.6205
# Epoch 4: val_loss improved from 0.44431 to 0.43600, saving model to /content/drive/MyDrive/mcrestnet_phase2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 456s 2s/step - accuracy: 0.8844 - loss: 0.6204 - val_accuracy: 0.9465 - val_loss: 0.4360 - learning_rate: 3.0000e-05
# Epoch 5/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9214 - loss: 0.5716
# Epoch 5: val_loss improved from 0.43600 to 0.41501, saving model to /content/drive/MyDrive/mcrestnet_phase2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 480s 2s/step - accuracy: 0.9214 - loss: 0.5717 - val_accuracy: 0.9520 - val_loss: 0.4150 - learning_rate: 3.0000e-05
# Epoch 6/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9117 - loss: 0.5808
# Epoch 6: val_loss did not improve from 0.41501
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.9116 - loss: 0.5809 - val_accuracy: 0.9400 - val_loss: 0.4335 - learning_rate: 3.0000e-05
# Epoch 7/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9114 - loss: 0.5776
# Epoch 7: val_loss did not improve from 0.41501
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 436s 2s/step - accuracy: 0.9114 - loss: 0.5776 - val_accuracy: 0.9446 - val_loss: 0.4265 - learning_rate: 3.0000e-05
# Epoch 8/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9149 - loss: 0.5938
# Epoch 8: val_loss did not improve from 0.41501
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 441s 2s/step - accuracy: 0.9149 - loss: 0.5938 - val_accuracy: 0.9340 - val_loss: 0.4415 - learning_rate: 3.0000e-05
# Epoch 9/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9396 - loss: 0.5447
# Epoch 9: val_loss did not improve from 0.41501
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 448s 2s/step - accuracy: 0.9396 - loss: 0.5448 - val_accuracy: 0.9405 - val_loss: 0.4331 - learning_rate: 3.0000e-05
# Epoch 10/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9299 - loss: 0.5451
# Epoch 10: val_loss did not improve from 0.41501
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 445s 2s/step - accuracy: 0.9299 - loss: 0.5452 - val_accuracy: 0.9437 - val_loss: 0.4204 - learning_rate: 1.5000e-05
# Epoch 11/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9350 - loss: 0.5348
# Epoch 11: val_loss did not improve from 0.41501
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 448s 2s/step - accuracy: 0.9350 - loss: 0.5348 - val_accuracy: 0.9377 - val_loss: 0.4341 - learning_rate: 1.5000e-05
# Epoch 12/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9330 - loss: 0.5533
# Epoch 12: val_loss did not improve from 0.41501
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 452s 2s/step - accuracy: 0.9330 - loss: 0.5534 - val_accuracy: 0.9419 - val_loss: 0.4213 - learning_rate: 1.5000e-05
# Restoring model weights from the end of the best epoch: 5.

# %%
# ---------------------------------------
# FULL PHASE-2 EVALUATION (ALL METRICS + ROC + AUC + CURVES)
# ---------------------------------------

from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import cv2
import skimage.color
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# ------------ PATHS ----------------
test_path = "/content/drive/MyDrive/gan_graphics_real/split_data/test"
model_path = "/content/drive/MyDrive/mcrestnet_phase2.h5"
log_path   = "/content/drive/MyDrive/phase2_training_log.csv"
img_size = (224,224)

# ------------ LOAD MODEL ------------
model = load_model(model_path, compile=False)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

print("✓ Phase-2 model loaded!")

# ------------ PREPROCESSING ----------
def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn, mx = np.min(a[:,:,i]), np.max(a[:,:,i])
        a[:,:,i] = ((a[:,:,i]-mn)/(mx-mn))*255 if mx!=mn else 0
    return a.astype(np.uint8)

def log_filter(image):
    g = cv2.GaussianBlur(image, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    return np.uint8(np.clip(image + lap, 0, 255))

def to_lch(batch):
    out=[]
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        out.append(scale0to255(skimage.color.lab2lch(lab)))
    return np.stack(out)

def to_hsv(batch):
    out=[]
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        out.append(scale0to255(np.nan_to_num(hsv)))
    return np.stack(out)

# ---------- TEST GENERATOR ----------
test_aug = ImageDataGenerator()

test_flow = test_aug.flow_from_directory(
    test_path,
    target_size=img_size,
    batch_size=32,   # FAST evaluation
    class_mode='categorical',
    shuffle=False
)

# -------- FAST BATCHED EVALUATION --------
y_true = []
prob_list = []

steps = int(np.ceil(test_flow.n / 32))
test_flow.reset()

for _ in tqdm(range(steps)):
    x_batch, y_batch = next(test_flow)

    x_uint8 = x_batch.astype(np.uint8)

    lch_batch = to_lch(x_uint8)
    hsv_batch = to_hsv(x_uint8)

    x_rgb = tf.keras.applications.resnet.preprocess_input(x_batch.astype(np.float32))
    x_lch = tf.keras.applications.resnet.preprocess_input(lch_batch.astype(np.float32))
    x_hsv = tf.keras.applications.resnet.preprocess_input(hsv_batch.astype(np.float32))

    preds = model.predict([x_rgb, x_lch, x_hsv], verbose=0)

    prob_list.extend(preds)
    y_true.extend(np.argmax(y_batch, axis=1))

probs = np.array(prob_list)
y_pred = np.argmax(probs, axis=1)

# -------- LABEL MAPPING --------
labels_map = {v:k for k,v in test_flow.class_indices.items()}
class_names = list(labels_map.values())

# -------- CLASSIFICATION REPORT --------
print("\n===== CLASSIFICATION REPORT (Phase-2) =====\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# -------- CONFUSION MATRIX --------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix (Phase-2)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# -------- ROC + AUC --------
y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes=len(class_names))

plt.figure(figsize=(8,6))
for i, cname in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_onehot[:,i], probs[:,i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{cname} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], linestyle='--')
plt.title("ROC Curves (Phase-2)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid()
plt.show()

# -------- SAVE CSV --------
df = pd.DataFrame(probs, columns=[f"Conf_{c}" for c in class_names])
df["True"] = [labels_map[i] for i in y_true]
df["Pred"] = [labels_map[i] for i in y_pred]

df.to_csv("phase2_full_metrics.csv", index=False)
print("✓ Saved → phase2_full_metrics.csv")

# =====================================================
#         TRAINING CURVES (loss + accuracy)
# =====================================================

print("\n===== PLOTTING TRAINING CURVES =====")

try:
    history = pd.read_csv(log_path)

    # ---- LOSS CURVE ----
    plt.figure(figsize=(7,5))
    plt.plot(history["loss"], label="Train Loss")
    plt.plot(history["val_loss"], label="Val Loss")
    plt.title("Phase-2 Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid()
    plt.show()

    # ---- ACCURACY CURVE ----
    plt.figure(figsize=(7,5))
    plt.plot(history["accuracy"], label="Train Acc")
    plt.plot(history["val_accuracy"], label="Val Acc")
    plt.title("Phase-2 Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid()
    plt.show()

except:
    print("⚠ phase2_training_log.csv not found. Cannot plot curves.")

print("\n🎉 Phase-2 evaluation complete (ALL METRICS INCLUDED)!")
# Out:
# ✓ Phase-2 model loaded!
# Found 2199 images belonging to 3 classes.
# 100%|██████████| 69/69 [02:27<00:00,  2.13s/it]
# ===== CLASSIFICATION REPORT (Phase-2) =====
#
#               precision    recall  f1-score   support
#
#          gan       0.99      0.93      0.96       800
#     graphics       0.92      0.94      0.93       800
#         real       0.88      0.93      0.91       599
#
#     accuracy                           0.94      2199
#    macro avg       0.93      0.94      0.93      2199
# weighted avg       0.94      0.94      0.94      2199
# ✓ Saved → phase2_full_metrics.csv
#
# ===== PLOTTING TRAINING CURVES =====
# 🎉 Phase-2 evaluation complete (ALL METRICS INCLUDED)!

# %%
# ---------------------------------------
# FINAL PHASE-3 TRAINING CODE
# ---------------------------------------

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
import cv2, skimage.color

# ------------------ PATHS ------------------
train_path = "/content/drive/MyDrive/gan_graphics_real/split_data/train"
val_path   = "/content/drive/MyDrive/gan_graphics_real/split_data/val"

phase2_ckpt = "/content/drive/MyDrive/mcrestnet_phase2.h5"
phase3_best = "/content/drive/MyDrive/mcrestnet_phase3.h5"
phase3_epoch_save = "/content/drive/MyDrive/phase3_epoch_{epoch:02d}.h5"
log_path = "/content/drive/MyDrive/phase3_training_log.csv"

img_size = (224,224)
batch_size = 32
phase3_epochs = 12
MIXUP_ALPHA = 0.2
USE_MIXUP = True
num_classes = 3

# ------------------ LOAD PHASE-2 CHECKPOINT ------------------
model = load_model(phase2_ckpt, compile=False)
print("Loaded Phase-2 best model!")

# ------------------ UNFREEZE ALL LAYERS ------------------
b1 = [layer for layer in model.layers if layer.name.startswith("r1_layer")]
b2 = [layer for layer in model.layers if layer.name.startswith("r2_layer")]
b3 = [layer for layer in model.layers if layer.name.startswith("r3_layer")]

for layer in b1: layer.trainable = True
for layer in b2: layer.trainable = True
for layer in b3: layer.trainable = True

print("All branch layers unfrozen for Phase-3!")

# ------------------ RE-COMPILE MODEL ------------------
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

model.compile(
    optimizer=Adam(learning_rate=5e-6),
    loss=loss_fn,
    metrics=["accuracy"]
)

print("Model recompiled for Phase-3 training!")

# ------------------ PREPROCESSING FUNCTIONS ------------------
def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn, mx = np.min(a[:,:,i]), np.max(a[:,:,i])
        a[:,:,i] = ((a[:,:,i]-mn)/(mx-mn))*255 if mx!=mn else 0
    return a.astype(np.uint8)

def log_filter(img):
    g = cv2.GaussianBlur(img, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    return np.uint8(np.clip(img + lap, 0, 255))

def to_lch(batch):
    out=[]
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        out.append(scale0to255(skimage.color.lab2lch(lab)))
    return np.stack(out)

def to_hsv(batch):
    out=[]
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        out.append(scale0to255(np.nan_to_num(hsv)))
    return np.stack(out)

def mixup(x, y, alpha=MIXUP_ALPHA):
    lam = np.random.beta(alpha, alpha)
    idx = np.random.permutation(x.shape[0])
    return lam*x + (1-lam)*x[idx], lam*y + (1-lam)*y[idx]

# ------------------ DATA LOADERS ------------------
aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.12,
    height_shift_range=0.12,
    shear_range=0.08,
    zoom_range=0.12,
    horizontal_flip=True,
    brightness_range=[0.75,1.25],
    fill_mode="reflect"
)

val_aug = ImageDataGenerator()

train_flow = aug.flow_from_directory(
    train_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_flow = val_aug.flow_from_directory(
    val_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ------------------ GENERATORS ------------------
def gen_train():
    while True:
        x, y = next(train_flow)
        x = x.astype(np.uint8)

        if USE_MIXUP:
            x, y = mixup(x, y)

        lch = to_lch(x)
        hsv = to_hsv(x)

        x_rgb = tf.keras.applications.resnet.preprocess_input(x.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv.astype(np.float32))

        yield (x_rgb, x_lch, x_hsv), y

def gen_val():
    while True:
        x, y = next(val_flow)
        x = x.astype(np.uint8)

        lch = to_lch(x)
        hsv = to_hsv(x)

        x_rgb = tf.keras.applications.resnet.preprocess_input(x.astype(np.float32))
        x_lch = tf.keras.applications.resnet.preprocess_input(lch.astype(np.float32))
        x_hsv = tf.keras.applications.resnet.preprocess_input(hsv.astype(np.float32))

        yield (x_rgb, x_lch, x_hsv), y

output_signature = (
    (
        tf.TensorSpec(shape=(None, img_size[0], img_size[1], 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, img_size[0], img_size[1], 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, img_size[0], img_size[1], 3), dtype=tf.float32),
    ),
    tf.TensorSpec(shape=(None, num_classes), dtype=tf.float32)
)

train_ds = tf.data.Dataset.from_generator(gen_train, output_signature=output_signature).prefetch(tf.data.AUTOTUNE)
val_ds   = tf.data.Dataset.from_generator(gen_val,   output_signature=output_signature).prefetch(tf.data.AUTOTUNE)

steps_per_epoch = train_flow.n // batch_size
val_steps = val_flow.n // batch_size

# ------------------ CHECKPOINTS ------------------
checkpoint_best = ModelCheckpoint(
    phase3_best,
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

checkpoint_all = ModelCheckpoint(
    phase3_epoch_save,
    verbose=1,
    save_freq="epoch"
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-8,
    verbose=1
)

early = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

csvlog = CSVLogger(log_path)

# ------------------ TRAIN PHASE-3 ------------------
print("\n🚀 Starting Phase-3 Training...\n")

model.fit(
    train_ds,
    epochs=phase3_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=val_steps,
    callbacks=[checkpoint_best, checkpoint_all, reduce_lr, early, csvlog]
)

print("\n🎉 Phase-3 training complete!")
# Out:
# Loaded Phase-2 best model!
# All branch layers unfrozen for Phase-3!
# Model recompiled for Phase-3 training!
# Found 6594 images belonging to 3 classes.
# Found 2199 images belonging to 3 classes.
#
# 🚀 Starting Phase-3 Training...
#
# Epoch 1/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8948 - loss: 0.6193
# Epoch 1: val_loss improved from inf to 0.44881, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: saving model to /content/drive/MyDrive/phase3_epoch_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 747s 3s/step - accuracy: 0.8948 - loss: 0.6191 - val_accuracy: 0.9370 - val_loss: 0.4488 - learning_rate: 5.0000e-06
# Epoch 2/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9113 - loss: 0.5871
# Epoch 2: val_loss improved from 0.44881 to 0.43939, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: saving model to /content/drive/MyDrive/phase3_epoch_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 805s 4s/step - accuracy: 0.9113 - loss: 0.5872 - val_accuracy: 0.9423 - val_loss: 0.4394 - learning_rate: 5.0000e-06
# Epoch 3/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9062 - loss: 0.6030
# Epoch 3: val_loss did not improve from 0.43939
#
# Epoch 3: saving model to /content/drive/MyDrive/phase3_epoch_03.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 578s 3s/step - accuracy: 0.9061 - loss: 0.6030 - val_accuracy: 0.9345 - val_loss: 0.4449 - learning_rate: 5.0000e-06
# Epoch 4/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9322 - loss: 0.5554
# Epoch 4: val_loss improved from 0.43939 to 0.43729, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: saving model to /content/drive/MyDrive/phase3_epoch_04.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 692s 3s/step - accuracy: 0.9321 - loss: 0.5555 - val_accuracy: 0.9405 - val_loss: 0.4373 - learning_rate: 5.0000e-06
# Epoch 5/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9174 - loss: 0.5976
# Epoch 5: val_loss improved from 0.43729 to 0.43638, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: saving model to /content/drive/MyDrive/phase3_epoch_05.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 739s 4s/step - accuracy: 0.9174 - loss: 0.5976 - val_accuracy: 0.9400 - val_loss: 0.4364 - learning_rate: 5.0000e-06
# Epoch 6/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9214 - loss: 0.5748
# Epoch 6: val_loss improved from 0.43638 to 0.43282, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: saving model to /content/drive/MyDrive/phase3_epoch_06.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 746s 4s/step - accuracy: 0.9214 - loss: 0.5748 - val_accuracy: 0.9395 - val_loss: 0.4328 - learning_rate: 5.0000e-06
# Epoch 7/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9216 - loss: 0.5799
# Epoch 7: val_loss improved from 0.43282 to 0.42663, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: saving model to /content/drive/MyDrive/phase3_epoch_07.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 741s 4s/step - accuracy: 0.9216 - loss: 0.5798 - val_accuracy: 0.9474 - val_loss: 0.4266 - learning_rate: 5.0000e-06
# Epoch 8/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9190 - loss: 0.5692
# Epoch 8: val_loss improved from 0.42663 to 0.42365, saving model to /content/drive/MyDrive/mcrestnet_phase3.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: saving model to /content/drive/MyDrive/phase3_epoch_08.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 775s 4s/step - accuracy: 0.9190 - loss: 0.5692 - val_accuracy: 0.9488 - val_loss: 0.4237 - learning_rate: 5.0000e-06
# Epoch 9/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9179 - loss: 0.5752
# Epoch 9: val_loss did not improve from 0.42365
#
# Epoch 9: saving model to /content/drive/MyDrive/phase3_epoch_09.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.9179 - loss: 0.5752 - val_accuracy: 0.9455 - val_loss: 0.4284 - learning_rate: 5.0000e-06
# Epoch 10/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9279 - loss: 0.5727
# Epoch 10: val_loss did not improve from 0.42365
#
# Epoch 10: saving model to /content/drive/MyDrive/phase3_epoch_10.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 586s 3s/step - accuracy: 0.9279 - loss: 0.5728 - val_accuracy: 0.9469 - val_loss: 0.4244 - learning_rate: 5.0000e-06
# Epoch 11/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9207 - loss: 0.5741
# Epoch 11: val_loss did not improve from 0.42365
#
# Epoch 11: saving model to /content/drive/MyDrive/phase3_epoch_11.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 569s 3s/step - accuracy: 0.9208 - loss: 0.5740 - val_accuracy: 0.9460 - val_loss: 0.4290 - learning_rate: 5.0000e-06
# Epoch 12/12
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9277 - loss: 0.5648
# Epoch 12: val_loss did not improve from 0.42365
#
# Epoch 12: saving model to /content/drive/MyDrive/phase3_epoch_12.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 564s 3s/step - accuracy: 0.9276 - loss: 0.5648 - val_accuracy: 0.9428 - val_loss: 0.4317 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 8.
#
# 🎉 Phase-3 training complete!

# %%
# ---------------------------------------
# FULL PHASE-3 EVALUATION (ALL METRICS)
# ---------------------------------------

from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import cv2
import skimage.color
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# ------------ PATHS ----------------
test_path = "/content/drive/MyDrive/gan_graphics_real/split_data/test"
model_path = "/content/drive/MyDrive/mcrestnet_phase3.h5"
img_size = (224,224)

# ------------ LOAD MODEL ------------
model = load_model(model_path, compile=False)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
print("✓ Phase-3 best model loaded!")

# ------------ PREPROCESSING ----------
def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn, mx = np.min(a[:,:,i]), np.max(a[:,:,i])
        a[:,:,i] = ((a[:,:,i]-mn)/(mx-mn))*255 if mx!=mn else 0
    return a.astype(np.uint8)

def log_filter(image):
    g = cv2.GaussianBlur(image, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    return np.uint8(np.clip(image + lap, 0, 255))

def to_lch(batch):
    out=[]
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        out.append(scale0to255(skimage.color.lab2lch(lab)))
    return np.stack(out)

def to_hsv(batch):
    out=[]
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        out.append(scale0to255(np.nan_to_num(hsv)))
    return np.stack(out)

# ---------- TEST GENERATOR ----------
test_aug = ImageDataGenerator()

test_flow = test_aug.flow_from_directory(
    test_path,
    target_size=img_size,
    batch_size=32,   # FAST evaluation
    class_mode='categorical',
    shuffle=False
)

# -------- FAST BATCHED EVALUATION --------
y_true = []
prob_list = []

steps = int(np.ceil(test_flow.n / 32))
test_flow.reset()

for _ in tqdm(range(steps)):
    x_batch, y_batch = next(test_flow)

    x_uint8 = x_batch.astype(np.uint8)

    lch_batch = to_lch(x_uint8)
    hsv_batch = to_hsv(x_uint8)

    x_rgb = tf.keras.applications.resnet.preprocess_input(x_batch.astype(np.float32))
    x_lch = tf.keras.applications.resnet.preprocess_input(lch_batch.astype(np.float32))
    x_hsv = tf.keras.applications.resnet.preprocess_input(hsv_batch.astype(np.float32))

    preds = model.predict([x_rgb, x_lch, x_hsv], verbose=0)

    prob_list.extend(preds)
    y_true.extend(np.argmax(y_batch, axis=1))

probs = np.array(prob_list)
y_pred = np.argmax(probs, axis=1)

print("✓ Phase-3 predictions complete!")

# -------- LABEL MAPPING --------
labels_map = {v:k for k,v in test_flow.class_indices.items()}
class_names = list(labels_map.values())

# -------- CLASSIFICATION REPORT --------
print("\n===== CLASSIFICATION REPORT (Phase-3) =====\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# -------- CONFUSION MATRIX --------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix (Phase-3)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# -------- ROC + AUC --------
y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes=len(class_names))

plt.figure(figsize=(8,6))
for i, cname in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_onehot[:,i], probs[:,i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{cname} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], linestyle='--')
plt.title("ROC Curves (Phase-3)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid()
plt.show()

# -------- SAVE CSV --------
df = pd.DataFrame(probs, columns=[f"Conf_{c}" for c in class_names])
df["True"] = [labels_map[i] for i in y_true]
df["Pred"] = [labels_map[i] for i in y_pred]

df.to_csv("phase3_full_metrics.csv", index=False)
print("\n✓ Saved → phase3_full_metrics.csv")

print("\n🎉 Phase-3 evaluation complete!")
# Out:
# ✓ Phase-3 best model loaded!
# Found 2199 images belonging to 3 classes.
# 100%|██████████| 69/69 [02:17<00:00,  2.00s/it]
# ✓ Phase-3 predictions complete!
#
# ===== CLASSIFICATION REPORT (Phase-3) =====
#
#               precision    recall  f1-score   support
#
#          gan       0.99      0.91      0.95       800
#     graphics       0.92      0.95      0.93       800
#         real       0.87      0.93      0.90       599
#
#     accuracy                           0.93      2199
#    macro avg       0.93      0.93      0.93      2199
# weighted avg       0.93      0.93      0.93      2199
# ✓ Saved → phase3_full_metrics.csv
#
# 🎉 Phase-3 evaluation complete!

# %%
import pandas as pd
import matplotlib.pyplot as plt

log_path = "/content/drive/MyDrive/phase3_training_log.csv"

try:
    history = pd.read_csv(log_path)
    print("✓ Training log loaded!")

    # ---- LOSS CURVE ----
    plt.figure(figsize=(7,5))
    plt.plot(history["loss"], label="Train Loss")
    plt.plot(history["val_loss"], label="Val Loss")
    plt.title("Phase-3 Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid()
    plt.show()

    # ---- ACCURACY CURVE ----
    plt.figure(figsize=(7,5))
    plt.plot(history["accuracy"], label="Train Acc")
    plt.plot(history["val_accuracy"], label="Val Acc")
    plt.title("Phase-3 Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid()
    plt.show()

except:
    print("⚠ phase3_training_log.csv not found. Train Phase-3 again or check path.")
# Out:
# ✓ Training log loaded!

# %%
from tensorflow.keras.models import load_model

model_path = "/content/drive/MyDrive/mcrestnet_phase3.h5"
model = load_model(model_path, compile=False)
import numpy as np
import cv2
import skimage.color

def scale0to255(image):
    a = image.astype(np.float32)
    for i in range(3):
        mn, mx = np.min(a[:,:,i]), np.max(a[:,:,i])
        a[:,:,i] = ((a[:,:,i]-mn)/(mx-mn))*255 if mx!=mn else 0
    return a.astype(np.uint8)

def log_filter(img):
    g = cv2.GaussianBlur(img, (3,3), 0)
    lap = cv2.Laplacian(np.uint8(g), cv2.CV_64F)
    return np.uint8(np.clip(img + lap, 0, 255))

def to_lch(batch):
    out=[]
    for img in batch:
        lab = skimage.color.rgb2lab(log_filter(img))
        out.append(scale0to255(skimage.color.lab2lch(lab)))
    return np.stack(out)

def to_hsv(batch):
    out=[]
    for img in batch:
        hsv = skimage.color.rgb2hsv(log_filter(img))
        out.append(scale0to255(np.nan_to_num(hsv)))
    return np.stack(out)



import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

def grad_cam_resnet50_phase3(model,
                             img_rgb_uint8,
                             layer_name,
                             H=224, W=224):
    """
    model: your 3-input Phase-3 ResNet50 model
    img_rgb_uint8: single RGB image (uint8) BEFORE preprocessing
    layer_name: target conv layer name from RGB branch
    """

    # --- 1. Preprocess all 3 branches ---
    x = img_rgb_uint8.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    # Convert using your LCH/HSV preprocessing
    lch = to_lch(img_rgb_uint8[np.newaxis, ...])
    hsv = to_hsv(img_rgb_uint8[np.newaxis, ...])

    x_rgb = tf.keras.applications.resnet.preprocess_input(x)
    x_lch = tf.keras.applications.resnet.preprocess_input(lch.astype(np.float32))
    x_hsv = tf.keras.applications.resnet.preprocess_input(hsv.astype(np.float32))

    # --- 2. Get the correct layer ---
    target_layer = model.get_layer(layer_name)

    # --- 3. Build grad model ---
    grad_model = tf.keras.models.Model(
        inputs=model.inputs,
        outputs=[target_layer.output, model.output]
    )

    # --- 4. Compute gradient ---
    with tf.GradientTape() as tape:
        conv_out, preds = grad_model([x_rgb, x_lch, x_hsv])
        pred_index = tf.argmax(preds[0])
        class_output = preds[:, pred_index]

    grads = tape.gradient(class_output, conv_out)

    # --- 5. Compute weights ---
    weights = tf.reduce_mean(grads, axis=(0,1,2))
    cam = tf.reduce_sum(tf.multiply(weights, conv_out[0]), axis=-1).numpy()

    # --- 6. Normalize CAM ---
    cam = np.maximum(cam, 0)
    cam = cam / (cam.max() + 1e-8)

    # Resize to image size
    cam = cv2.resize(cam, (W, H))

    return cam

# %%
img_path = "/content/drive/MyDrive/gan_graphics_real/split_data/test/real/freeFoto_01_48_31_prev.jpg"

orig = cv2.imread(img_path)
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)
orig_resized = cv2.resize(orig, (224,224))

cam = grad_cam_resnet50_phase3(
    model,
    orig_resized,
    layer_name="r1_layer_174"
)


plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(orig_resized)
plt.title("Original")

plt.subplot(1,2,2)
plt.imshow(orig_resized)
plt.imshow(cam, cmap="jet", alpha=0.6)
plt.title("Grad-CAM")
plt.show()

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# r1_layer_0
# r2_layer_0
# r3_layer_0
# r1_layer_1
# r2_layer_1
# r3_layer_1
# r1_layer_2
# r2_layer_2
# r3_layer_2
# r1_layer_3
# r2_layer_3
# r3_layer_3
# r1_layer_4
# r2_layer_4
# r3_layer_4
# r1_layer_5
# r2_layer_5
# r3_layer_5
# r1_layer_6
# r2_layer_6
# r3_layer_6
# r1_layer_7
# r2_layer_7
# r3_layer_7
# r1_layer_8
# r2_layer_8
# r3_layer_8
# r1_layer_9
# r2_layer_9
# r3_layer_9
# r1_layer_10
# r2_layer_10
# r3_layer_10
# r1_layer_11
# r2_layer_11
# r3_layer_11
# r1_layer_12
# r2_layer_12
# r3_layer_12
# r1_layer_13
# r1_layer_14
# r2_layer_13
# r2_layer_14
# r3_layer_13
# r3_layer_14
# r1_layer_15
# r1_layer_16
# r2_layer_15
# r2_layer_16
# r3_layer_15
# r3_layer_16
# r1_layer_17
# r2_layer_17
# r3_layer_17
# r1_layer_18
# r2_layer_18
# r3_layer_18
# r1_layer_19
# r2_layer_19
# r3_layer_19
# r1_layer_20
# r2_layer_20
# r3_layer_20
# r1_layer_21
# r2_layer_21
# r3_layer_21
# r1_layer_22
# r2_layer_22
# r3_layer_22
# r1_layer_23
# r2_layer_23
# r3_layer_23
# r1_layer_24
# r2_layer_24
# r3_layer_24
# r1_layer_25
# r2_layer_25
# r3_layer_25
# r1_layer_26
# r2_layer_26
# r3_layer_26
# r1_layer_27
# r2_layer_27
# r3_layer_27
# r1_layer_28
# r2_layer_28
# r3_layer_28
# r1_layer_29
# r2_layer_29
# r3_layer_29
# r1_layer_30
# r2_layer_30
# r3_layer_30
# r1_layer_31
# r2_layer_31
# r3_layer_31
# r1_layer_32
# r2_layer_32
# r3_layer_32
# r1_layer_33
# r2_layer_33
# r3_layer_33
# r1_layer_34
# r2_layer_34
# r3_layer_34
# r1_layer_35
# r2_layer_35
# r3_layer_35
# r1_layer_36
# r2_layer_36
# r3_layer_36
# r1_layer_37
# r2_layer_37
# r3_layer_37
# r1_layer_38
# r2_layer_38
# r3_layer_38
# r1_layer_39
# r2_layer_39
# r3_layer_39
# r1_layer_40
# r2_layer_40
# r3_layer_40
# r1_layer_41
# r2_layer_41
# r3_layer_41
# r1_layer_42
# r2_layer_42
# r3_layer_42
# r1_layer_43
# r2_layer_43
# r3_layer_43
# r1_layer_44
# r2_layer_44
# r3_layer_44
# r1_layer_45
# r1_layer_46
# r2_layer_45
# r2_layer_46
# r3_layer_45
# r3_layer_46
# r1_layer_47
# r1_layer_48
# r2_layer_47
# r2_layer_48
# r3_layer_47
# r3_layer_48
# r1_layer_49
# r2_layer_49
# r3_layer_49
# r1_layer_50
# r2_layer_50
# r3_layer_50
# r1_layer_51
# r2_layer_51
# r3_layer_51
# r1_layer_52
# r2_layer_52
# r3_layer_52
# r1_layer_53
# r2_layer_53
# r3_layer_53
# r1_layer_54
# r2_layer_54
# r3_layer_54
# r1_layer_55
# r2_layer_55
# r3_layer_55
# r1_layer_56
# r2_layer_56
# r3_layer_56
# r1_layer_57
# r2_layer_57
# r3_layer_57
# r1_layer_58
# r2_layer_58
# r3_layer_58
# r1_layer_59
# r2_layer_59
# r3_layer_59
# r1_layer_60
# r2_layer_60
# r3_layer_60
# r1_layer_61
# r2_layer_61
# r3_layer_61
# r1_layer_62
# r2_layer_62
# r3_layer_62
# r1_layer_63
# r2_layer_63
# r3_layer_63
# r1_layer_64
# r2_layer_64
# r3_layer_64
# r1_layer_65
# r2_layer_65
# r3_layer_65
# r1_layer_66
# r2_layer_66
# r3_layer_66
# r1_layer_67
# r2_layer_67
# r3_layer_67
# r1_layer_68
# r2_layer_68
# r3_layer_68
# r1_layer_69
# r2_layer_69
# r3_layer_69
# r1_layer_70
# r2_layer_70
# r3_layer_70
# r1_layer_71
# r2_layer_71
# r3_layer_71
# r1_layer_72
# r2_layer_72
# r3_layer_72
# r1_layer_73
# r2_layer_73
# r3_layer_73
# r1_layer_74
# r2_layer_74
# r3_layer_74
# r1_layer_75
# r2_layer_75
# r3_layer_75
# r1_layer_76
# r2_layer_76
# r3_layer_76
# r1_layer_77
# r2_layer_77
# r3_layer_77
# r1_layer_78
# r2_layer_78
# r3_layer_78
# r1_layer_79
# r2_layer_79
# r3_layer_79
# r1_layer_80
# r2_layer_80
# r3_layer_80
# r1_layer_81
# r2_layer_81
# r3_layer_81
# r1_layer_82
# r2_layer_82
# r3_layer_82
# r1_layer_83
# r2_layer_83
# r3_layer_83
# r1_layer_84
# r2_layer_84
# r3_layer_84
# r1_layer_85
# r2_layer_85
# r3_layer_85
# r1_layer_86
# r2_layer_86
# r3_layer_86
# r1_layer_87
# r1_layer_88
# r2_layer_87
# r2_layer_88
# r3_layer_87
# r3_layer_88
# r1_layer_89
# r1_layer_90
# r2_layer_89
# r2_layer_90
# r3_layer_89
# r3_layer_90
# r1_layer_91
# r2_layer_91
# r3_layer_91
# r1_layer_92
# r2_layer_92
# r3_layer_92
# r1_layer_93
# r2_layer_93
# r3_layer_93
# r1_layer_94
# r2_layer_94
# r3_layer_94
# r1_layer_95
# r2_layer_95
# r3_layer_95
# r1_layer_96
# r2_layer_96
# r3_layer_96
# r1_layer_97
# r2_layer_97
# r3_layer_97
# r1_layer_98
# r2_layer_98
# r3_layer_98
# r1_layer_99
# r2_layer_99
# r3_layer_99
# r1_layer_100
# r2_layer_100
# r3_layer_100
# r1_layer_101
# r2_layer_101
# r3_layer_101
# r1_layer_102
# r2_layer_102
# r3_layer_102
# r1_layer_103
# r2_layer_103
# r3_layer_103
# r1_layer_104
# r2_layer_104
# r3_layer_104
# r1_layer_105
# r2_layer_105
# r3_layer_105
# r1_layer_106
# r2_layer_106
# r3_layer_106
# r1_layer_107
# r2_layer_107
# r3_layer_107
# r1_layer_108
# r2_layer_108
# r3_layer_108
# r1_layer_109
# r2_layer_109
# r3_layer_109
# r1_layer_110
# r2_layer_110
# r3_layer_110
# r1_layer_111
# r2_layer_111
# r3_layer_111
# r1_layer_112
# r2_layer_112
# r3_layer_112
# r1_layer_113
# r2_layer_113
# r3_layer_113
# r1_layer_114
# r2_layer_114
# r3_layer_114
# r1_layer_115
# r2_layer_115
# r3_layer_115
# r1_layer_116
# r2_layer_116
# r3_layer_116
# r1_layer_117
# r2_layer_117
# r3_layer_117
# r1_layer_118
# r2_layer_118
# r3_layer_118
# r1_layer_119
# r2_layer_119
# r3_layer_119
# r1_layer_120
# r2_layer_120
# r3_layer_120
# r1_layer_121
# r2_layer_121
# r3_layer_121
# r1_layer_122
# r2_layer_122
# r3_layer_122
# r1_layer_123
# r2_layer_123
# r3_layer_123
# r1_layer_124
# r2_layer_124
# r3_layer_124
# r1_layer_125
# r2_layer_125
# r3_layer_125
# r1_layer_126
# r2_layer_126
# r3_layer_126
# r1_layer_127
# r2_layer_127
# r3_layer_127
# r1_layer_128
# r2_layer_128
# r3_layer_128
# r1_layer_129
# r2_layer_129
# r3_layer_129
# r1_layer_130
# r2_layer_130
# r3_layer_130
# r1_layer_131
# r2_layer_131
# r3_layer_131
# r1_layer_132
# r2_layer_132
# r3_layer_132
# r1_layer_133
# r2_layer_133
# r3_layer_133
# r1_layer_134
# r2_layer_134
# r3_layer_134
# r1_layer_135
# r2_layer_135
# r3_layer_135
# r1_layer_136
# r2_layer_136
# r3_layer_136
# r1_layer_137
# r2_layer_137
# r3_layer_137
# r1_layer_138
# r2_layer_138
# r3_layer_138
# r1_layer_139
# r2_layer_139
# r3_layer_139
# r1_layer_140
# r2_layer_140
# r3_layer_140
# r1_layer_141
# r2_layer_141
# r3_layer_141
# r1_layer_142
# r2_layer_142
# r3_layer_142
# r1_layer_143
# r2_layer_143
# r3_layer_143
# r1_layer_144
# r2_layer_144
# r3_layer_144
# r1_layer_145
# r2_layer_145
# r3_layer_145
# r1_layer_146
# r2_layer_146
# r3_layer_146
# r1_layer_147
# r2_layer_147
# r3_layer_147
# r1_layer_148
# r2_layer_148
# r3_layer_148
# r1_layer_149
# r1_layer_150
# r2_layer_149
# r2_layer_150
# r3_layer_149
# r3_layer_150
# r1_layer_151
# r1_layer_152
# r2_layer_151
# r2_layer_152
# r3_layer_151
# r3_layer_152
# r1_layer_153
# r2_layer_153
# r3_layer_153
# r1_layer_154
# r2_layer_154
# r3_layer_154
# r1_layer_155
# r2_layer_155
# r3_layer_155
# r1_layer_156
# r2_layer_156
# r3_layer_156
# r1_layer_157
# r2_layer_157
# r3_layer_157
# r1_layer_158
# r2_layer_158
# r3_layer_158
# r1_layer_159
# r2_layer_159
# r3_layer_159
# r1_layer_160
# r2_layer_160
# r3_layer_160
# r1_layer_161
# r2_layer_161
# r3_layer_161
# r1_layer_162
# r2_layer_162
# r3_layer_162
# r1_layer_163
# r2_layer_163
# r3_layer_163
# r1_layer_164
# r2_layer_164
# r3_layer_164
# r1_layer_165
# r2_layer_165
# r3_layer_165
# r1_layer_166
# r2_layer_166
# r3_layer_166
# r1_layer_167
# r2_layer_167
# r3_layer_167
# r1_layer_168
# r2_layer_168
# r3_layer_168
# r1_layer_169
# r2_layer_169
# r3_layer_169
# r1_layer_170
# r2_layer_170
# r3_layer_170
# r1_layer_171
# r2_layer_171
# r3_layer_171
# r1_layer_172
# r2_layer_172
# r3_layer_172
# r1_layer_173
# r2_layer_173
# r3_layer_173
# r1_layer_174
# r2_layer_174
# r3_layer_174
# global_average_pooling2d_3
# global_average_pooling2d_4
# global_average_pooling2d_5
# concatenate_1
# dense_3
# batch_normalization_1
# dropout_2
# dense_4
# dropout_3
# dense_5
